# %%
#Importing Libraries

# %%
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_26980\432526209.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv(r'TWO_CENTURIES_OF_UM_RACES.csv')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_26980\1516503734.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r'TWO_CENTURIES_OF_UM_RACES.csv')

# %%
df.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#Data Cleaning
# Only 50k or 50Mi
#50km
#50mi
#Canada
#2018

# %%
df[df['Event distance/length'].isin(['50km','50mi'])  ]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 0                        50km                         22           4:51:39 h
# 1                        50km                         22           5:15:45 h
# 2                        50km                         22           5:16:44 h
# 3                        50km                         22           5:34:13 h
# 4                        50km                         22           5:54:14 h
# ...                       ...                        ...                 ...
# 7461181                  50mi                         92          11:59:37 h
# 7461182                  50mi                         92          12:01:41 h
# 7461183                  50mi                         92          12:03:26 h
# 7461184                  50mi                         92          12:03:26 h
# 7461185                  50mi                         92          12:05:59 h
#
#                Athlete club Athlete country  Athlete year of birth  \
# 0                     Tnfrc             CHI                 1978.0
# 1        Roberto Echeverría             CHI                 1981.0
# 2         Puro Trail Osorno             CHI                 1987.0
# 3                  Columbia             ARG                 1976.0
# 4            Baguales Trail             CHI                 1992.0
# ...                     ...             ...                    ...
# 7461181                 NaN             USA                 1941.0
# 7461182                 NaN             USA                 1932.0
# 7461183                 NaN             USA                 1934.0
# 7461184                 NaN             USA                 1951.0
# 7461185                 NaN             USA                 1947.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                    M                  M35                10.286           0
# 1                    M                  M35                 9.501           1
# 2                    M                  M23                 9.472           2
# 3                    M                  M40                 8.976           3
# 4                    M                  M23                 8.469           4
# ...                ...                  ...                   ...         ...
# 7461181              M                  M50                6709.0     1045603
# 7461182              M                  M60                6690.0     1070463
# 7461183              F                  W60                6674.0      416139
# 7461184              F                  W40                6674.0     1098098
# 7461185              F                  W45                6650.0     1626367
#
# [1874790 rows x 13 columns]

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2018)  ]
# Out:
#         Year of event     Event dates                 Event name  \
# 0                2018      06.01.2018        Selva Costera (CHI)
# 1                2018      06.01.2018        Selva Costera (CHI)
# 2                2018      06.01.2018        Selva Costera (CHI)
# 3                2018      06.01.2018        Selva Costera (CHI)
# 4                2018      06.01.2018        Selva Costera (CHI)
# ...               ...             ...                        ...
# 661478           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661479           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661480           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661481           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661482           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
#
#        Event distance/length  Event number of finishers Athlete performance  \
# 0                       50km                         22           4:51:39 h
# 1                       50km                         22           5:15:45 h
# 2                       50km                         22           5:16:44 h
# 3                       50km                         22           5:34:13 h
# 4                       50km                         22           5:54:14 h
# ...                      ...                        ...                 ...
# 661478                  50mi                         29          17:05:58 h
# 661479                  50mi                         29          18:13:01 h
# 661480                  50mi                         29          18:49:58 h
# 661481                  50mi                         29          23:30:00 h
# 661482                  50mi                         29          25:40:10 h
#
#               Athlete club Athlete country  Athlete year of birth  \
# 0                    Tnfrc             CHI                 1978.0
# 1       Roberto Echeverría             CHI                 1981.0
# 2        Puro Trail Osorno             CHI                 1987.0
# 3                 Columbia             ARG                 1976.0
# 4           Baguales Trail             CHI                 1992.0
# ...                    ...             ...                    ...
# 661478                 NaN             USA                 1972.0
# 661479                 NaN             USA                 1953.0
# 661480                 NaN             USA                 1986.0
# 661481                 NaN             USA                 1952.0
# 661482                 NaN             USA                 1951.0
#
#        Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                   M                  M35                10.286           0
# 1                   M                  M35                 9.501           1
# 2                   M                  M23                 9.472           2
# 3                   M                  M40                 8.976           3
# 4                   M                  M23                 8.469           4
# ...               ...                  ...                   ...         ...
# 661478              M                  M45                 4.706       68122
# 661479              M                  M65                 4.417       23336
# 661480              M                  M23                 4.273      375022
# 661481              M                  M65                 3.424       68273
# 661482              M                  M65                 3.135      341648
#
# [167243 rows x 13 columns]

# %%
df[df['Event name']=='The Bad Thing 50km Trail Race (CAN)']['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 495242     CAN
# 495243     CAN
# 495244     CAN
# 495245     CAN
# 495246     CAN
#           ...
# 3602202    CAN
# 3602203    CAN
# 3602204    CAN
# 3602205    CAN
# 3602206    CAN
# Name: Event name, Length: 360, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)=='CAN']
# Out:
#          Year of event Event dates  \
# 25299             2018  10.03.2018
# 25300             2018  10.03.2018
# 25301             2018  10.03.2018
# 25302             2018  10.03.2018
# 25303             2018  10.03.2018
# ...                ...         ...
# 7450076           1995  16.04.1995
# 7450077           1995  16.04.1995
# 7450078           1995  16.04.1995
# 7450079           1995  16.04.1995
# 7450080           1995  16.04.1995
#
#                                             Event name Event distance/length  \
# 25299                        Dirty Duo Trail Run (CAN)                  50km
# 25300                        Dirty Duo Trail Run (CAN)                  50km
# 25301                        Dirty Duo Trail Run (CAN)                  50km
# 25302                        Dirty Duo Trail Run (CAN)                  50km
# 25303                        Dirty Duo Trail Run (CAN)                  50km
# ...                                                ...                   ...
# 7450076  Penticton Speedy Printing Centers 50 Km (CAN)                  50km
# 7450077  Penticton Speedy Printing Centers 50 Km (CAN)                  50km
# 7450078  Penticton Speedy Printing Centers 50 Km (CAN)                  50km
# 7450079  Penticton Speedy Printing Centers 50 Km (CAN)                  50km
# 7450080  Penticton Speedy Printing Centers 50 Km (CAN)                  50km
#
#          Event number of finishers Athlete performance Athlete club  \
# 25299                           34           4:58:08 h          NaN
# 25300                           34           5:16:44 h          NaN
# 25301                           34           5:22:32 h          NaN
# 25302                           34           5:40:38 h          NaN
# 25303                           34           5:49:23 h          NaN
# ...                            ...                 ...          ...
# 7450076                          5           3:40:31 h          NaN
# 7450077                          5           3:46:22 h          NaN
# 7450078                          5           4:06:20 h          NaN
# 7450079                          5           4:15:02 h          NaN
# 7450080                          5           4:48:38 h          NaN
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 25299               IND                 1980.0              M
# 25300               CAN                 1984.0              M
# 25301               CAN                 1999.0              M
# 25302               CAN                 1986.0              M
# 25303               USA                 1994.0              F
# ...                 ...                    ...            ...
# 7450076             CAN                 1966.0              M
# 7450077             USA                 1958.0              M
# 7450078             CAN                 1959.0              F
# 7450079             CAN                    NaN              M
# 7450080             CAN                    NaN              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 25299                    M35                10.063       23912
# 25300                    M23                 9.472       23913
# 25301                   MU23                 9.301       23914
# 25302                    M23                 8.807       23915
# 25303                    W23                 8.587       23916
# ...                      ...                   ...         ...
# 7450076                  M23               13604.0     1001224
# 7450077                  M35               13253.0     1105362
# 7450078                  W35               12179.0     1052424
# 7450079                  NaN               11763.0     1640552
# 7450080                  NaN               10394.0     1640553
#
# [92628 rows x 13 columns]

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2018) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)=='CAN')]
# Out:
#         Year of event Event dates                  Event name  \
# 25299            2018  10.03.2018   Dirty Duo Trail Run (CAN)
# 25300            2018  10.03.2018   Dirty Duo Trail Run (CAN)
# 25301            2018  10.03.2018   Dirty Duo Trail Run (CAN)
# 25302            2018  10.03.2018   Dirty Duo Trail Run (CAN)
# 25303            2018  10.03.2018   Dirty Duo Trail Run (CAN)
# ...               ...         ...                         ...
# 636735           2018  10.11.2018   The Beav Trail Race (CAN)
# 655540           2018  27.10.2018  Horror Trail 50K Run (CAN)
# 655541           2018  27.10.2018  Horror Trail 50K Run (CAN)
# 655542           2018  27.10.2018  Horror Trail 50K Run (CAN)
# 655543           2018  27.10.2018  Horror Trail 50K Run (CAN)
#
#        Event distance/length  Event number of finishers Athlete performance  \
# 25299                   50km                         34           4:58:08 h
# 25300                   50km                         34           5:16:44 h
# 25301                   50km                         34           5:22:32 h
# 25302                   50km                         34           5:40:38 h
# 25303                   50km                         34           5:49:23 h
# ...                      ...                        ...                 ...
# 636735                  50km                         71           8:10:35 h
# 655540                  50km                          4           4:48:56 h
# 655541                  50km                          4           5:23:53 h
# 655542                  50km                          4           5:34:05 h
# 655543                  50km                          4           6:00:00 h
#
#        Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 25299           NaN             IND                 1980.0              M
# 25300           NaN             CAN                 1984.0              M
# 25301           NaN             CAN                 1999.0              M
# 25302           NaN             CAN                 1986.0              M
# 25303           NaN             USA                 1994.0              F
# ...             ...             ...                    ...            ...
# 636735    *Oakville             CAN                 1972.0              M
# 655540          NaN             CAN                 1983.0              F
# 655541          NaN             CAN                 1974.0              M
# 655542          NaN             CAN                 1973.0              M
# 655543          NaN             CAN                 1972.0              M
#
#        Athlete age category Athlete average speed  Athlete ID
# 25299                   M35                10.063       23912
# 25300                   M23                 9.472       23913
# 25301                  MU23                 9.301       23914
# 25302                   M23                 8.807       23915
# 25303                   W23                 8.587       23916
# ...                     ...                   ...         ...
# 636735                  M45                 6.115      304461
# 655540                  W23                10.383       19657
# 655541                  M40                 9.263       87133
# 655542                  M40                  8.98      223455
# 655543                  M45                 8.333      147600
#
# [4756 rows x 13 columns]

# %%
df2=df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2018) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)=='CAN')]

# %%
df2.head()
# Out:
#        Year of event Event dates                 Event name  \
# 25299           2018  10.03.2018  Dirty Duo Trail Run (CAN)
# 25300           2018  10.03.2018  Dirty Duo Trail Run (CAN)
# 25301           2018  10.03.2018  Dirty Duo Trail Run (CAN)
# 25302           2018  10.03.2018  Dirty Duo Trail Run (CAN)
# 25303           2018  10.03.2018  Dirty Duo Trail Run (CAN)
#
#       Event distance/length  Event number of finishers Athlete performance  \
# 25299                  50km                         34           4:58:08 h
# 25300                  50km                         34           5:16:44 h
# 25301                  50km                         34           5:22:32 h
# 25302                  50km                         34           5:40:38 h
# 25303                  50km                         34           5:49:23 h
#
#       Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 25299          NaN             IND                 1980.0              M
# 25300          NaN             CAN                 1984.0              M
# 25301          NaN             CAN                 1999.0              M
# 25302          NaN             CAN                 1986.0              M
# 25303          NaN             USA                 1994.0              F
#
#       Athlete age category Athlete average speed  Athlete ID
# 25299                  M35                10.063       23912
# 25300                  M23                 9.472       23913
# 25301                 MU23                 9.301       23914
# 25302                  M23                 8.807       23915
# 25303                  W23                 8.587       23916

# %%
df2.shape
# Out:
# (4756, 13)

# %%
df2['Event name']=df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_26980\2517910487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name']=df2['Event name'].str.split('(').str.get(0)

# %%
df2.head()
# Out:
#        Year of event Event dates            Event name Event distance/length  \
# 25299           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25300           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25301           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25302           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25303           2018  10.03.2018  Dirty Duo Trail Run                   50km
#
#        Event number of finishers Athlete performance Athlete club  \
# 25299                         34           4:58:08 h          NaN
# 25300                         34           5:16:44 h          NaN
# 25301                         34           5:22:32 h          NaN
# 25302                         34           5:40:38 h          NaN
# 25303                         34           5:49:23 h          NaN
#
#       Athlete country  Athlete year of birth Athlete gender  \
# 25299             IND                 1980.0              M
# 25300             CAN                 1984.0              M
# 25301             CAN                 1999.0              M
# 25302             CAN                 1986.0              M
# 25303             USA                 1994.0              F
#
#       Athlete age category Athlete average speed  Athlete ID
# 25299                  M35                10.063       23912
# 25300                  M23                 9.472       23913
# 25301                 MU23                 9.301       23914
# 25302                  M23                 8.807       23915
# 25303                  W23                 8.587       23916

# %%
#Athlete age

# %%
df2['athlete_age']=2018-df['Athlete year of birth']
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_26980\767645356.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age']=2018-df['Athlete year of birth']

# %%
#Athlete Prformance

# %%
df2['Athlete performance']=df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_26980\2382045920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance']=df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head()
# Out:
#        Year of event Event dates            Event name Event distance/length  \
# 25299           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25300           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25301           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25302           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25303           2018  10.03.2018  Dirty Duo Trail Run                   50km
#
#        Event number of finishers Athlete performance Athlete club  \
# 25299                         34             4:58:08          NaN
# 25300                         34             5:16:44          NaN
# 25301                         34             5:22:32          NaN
# 25302                         34             5:40:38          NaN
# 25303                         34             5:49:23          NaN
#
#       Athlete country  Athlete year of birth Athlete gender  \
# 25299             IND                 1980.0              M
# 25300             CAN                 1984.0              M
# 25301             CAN                 1999.0              M
# 25302             CAN                 1986.0              M
# 25303             USA                 1994.0              F
#
#       Athlete age category Athlete average speed  Athlete ID  athlete_age
# 25299                  M35                10.063       23912         38.0
# 25300                  M23                 9.472       23913         34.0
# 25301                 MU23                 9.301       23914         19.0
# 25302                  M23                 8.807       23915         32.0
# 25303                  W23                 8.587       23916         24.0

# %%
df2=df2.drop(['Athlete club','Athlete country','Athlete year of birth','Athlete age category'],axis=1)

# %%
df2.head()
# Out:
#        Year of event Event dates            Event name Event distance/length  \
# 25299           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25300           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25301           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25302           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25303           2018  10.03.2018  Dirty Duo Trail Run                   50km
#
#        Event number of finishers Athlete performance Athlete gender  \
# 25299                         34             4:58:08              M
# 25300                         34             5:16:44              M
# 25301                         34             5:22:32              M
# 25302                         34             5:40:38              M
# 25303                         34             5:49:23              F
#
#       Athlete average speed  Athlete ID  athlete_age
# 25299                10.063       23912         38.0
# 25300                 9.472       23913         34.0
# 25301                 9.301       23914         19.0
# 25302                 8.807       23915         32.0
# 25303                 8.587       23916         24.0

# %%
df2.isnull().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# athlete_age                  426
# dtype: int64

# %%
df2[df2['athlete_age'].isnull()==1]
# Out:
#         Year of event Event dates                         Event name  \
# 25309            2018  10.03.2018               Dirty Duo Trail Run
# 25310            2018  10.03.2018               Dirty Duo Trail Run
# 25319            2018  10.03.2018               Dirty Duo Trail Run
# 76706            2018  20.01.2018   Winter River Valley Revenge 50k
# 76707            2018  20.01.2018   Winter River Valley Revenge 50k
# ...               ...         ...                                ...
# 516373           2018  20.10.2018  Relentless at the Ark Trail Race
# 516375           2018  20.10.2018  Relentless at the Ark Trail Race
# 516376           2018  20.10.2018  Relentless at the Ark Trail Race
# 516377           2018  20.10.2018  Relentless at the Ark Trail Race
# 516379           2018  20.10.2018  Relentless at the Ark Trail Race
#
#        Event distance/length  Event number of finishers Athlete performance  \
# 25309                   50km                         34             6:18:32
# 25310                   50km                         34             6:22:23
# 25319                   50km                         34             7:12:23
# 76706                   50km                         35             6:58:00
# 76707                   50km                         35             7:03:16
# ...                      ...                        ...                 ...
# 516373                  50km                         11             6:02:24
# 516375                  50km                         11             6:11:27
# 516376                  50km                         11             6:17:16
# 516377                  50km                         11             6:32:28
# 516379                  50km                         11             7:02:20
#
#        Athlete gender Athlete average speed  Athlete ID  athlete_age
# 25309               M                 7.925       23922          NaN
# 25310               F                 7.846       23923          NaN
# 25319               M                 6.938       23931          NaN
# 76706               M                 7.177       27097          NaN
# 76707               M                 7.088       65354          NaN
# ...               ...                   ...         ...          ...
# 516373              M                 8.278      314391          NaN
# 516375              M                 8.076      314393          NaN
# 516376              M                 7.952      314394          NaN
# 516377              M                 7.644      314395          NaN
# 516379              M                 7.103      314397          NaN
#
# [426 rows x 10 columns]

# %%
#Checing for null values and uplicate values

# %%
df2=df2.dropna()

# %%
df2.shape
# Out:
# (4330, 10)

# %%
df2[df2.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
#Index

# %%
df2.reset_index(drop=True)
# Out:
#       Year of event Event dates             Event name Event distance/length  \
# 0              2018  10.03.2018   Dirty Duo Trail Run                   50km
# 1              2018  10.03.2018   Dirty Duo Trail Run                   50km
# 2              2018  10.03.2018   Dirty Duo Trail Run                   50km
# 3              2018  10.03.2018   Dirty Duo Trail Run                   50km
# 4              2018  10.03.2018   Dirty Duo Trail Run                   50km
# ...             ...         ...                    ...                   ...
# 4325           2018  10.11.2018   The Beav Trail Race                   50km
# 4326           2018  27.10.2018  Horror Trail 50K Run                   50km
# 4327           2018  27.10.2018  Horror Trail 50K Run                   50km
# 4328           2018  27.10.2018  Horror Trail 50K Run                   50km
# 4329           2018  27.10.2018  Horror Trail 50K Run                   50km
#
#       Event number of finishers Athlete performance Athlete gender  \
# 0                            34             4:58:08              M
# 1                            34             5:16:44              M
# 2                            34             5:22:32              M
# 3                            34             5:40:38              M
# 4                            34             5:49:23              F
# ...                         ...                 ...            ...
# 4325                         71             8:10:35              M
# 4326                          4             4:48:56              F
# 4327                          4             5:23:53              M
# 4328                          4             5:34:05              M
# 4329                          4             6:00:00              M
#
#      Athlete average speed  Athlete ID  athlete_age
# 0                   10.063       23912         38.0
# 1                    9.472       23913         34.0
# 2                    9.301       23914         19.0
# 3                    8.807       23915         32.0
# 4                    8.587       23916         24.0
# ...                    ...         ...          ...
# 4325                 6.115      304461         46.0
# 4326                10.383       19657         35.0
# 4327                 9.263       87133         44.0
# 4328                  8.98      223455         45.0
# 4329                 8.333      147600         46.0
#
# [4330 rows x 10 columns]

# %%
#Data Types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# athlete_age                  float64
# dtype: object

# %%
df2['athlete_age']=df2['athlete_age'].astype(int)

# %%
df2['Athlete average speed']=df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int32
# dtype: object

# %%
df2.head()
# Out:
#        Year of event Event dates            Event name Event distance/length  \
# 25299           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25300           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25301           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25302           2018  10.03.2018  Dirty Duo Trail Run                   50km
# 25303           2018  10.03.2018  Dirty Duo Trail Run                   50km
#
#        Event number of finishers Athlete performance Athlete gender  \
# 25299                         34             4:58:08              M
# 25300                         34             5:16:44              M
# 25301                         34             5:22:32              M
# 25302                         34             5:40:38              M
# 25303                         34             5:49:23              F
#
#        Athlete average speed  Athlete ID  athlete_age
# 25299                 10.063       23912           38
# 25300                  9.472       23913           34
# 25301                  9.301       23914           19
# 25302                  8.807       23915           32
# 25303                  8.587       23916           24

# %%
#Renaming Columns

# %%
df2=df2.rename(columns={'Year of event':'year',
'Event dates':'race_day',
'Event name':'race_name',
'Event distance/length':'race_length',
'Event number of finishers':'race_number_of_finishers',
'Athlete performance':'athlete_performance',
'Athlete gender':'athlete_gender',
'Athlete average speed':'athlete_average_speed',
'Athlete ID':'athlete_id'
})

# %%
df2.head()
# Out:
#        year    race_day             race_name race_length  \
# 25299  2018  10.03.2018  Dirty Duo Trail Run         50km
# 25300  2018  10.03.2018  Dirty Duo Trail Run         50km
# 25301  2018  10.03.2018  Dirty Duo Trail Run         50km
# 25302  2018  10.03.2018  Dirty Duo Trail Run         50km
# 25303  2018  10.03.2018  Dirty Duo Trail Run         50km
#
#        race_number_of_finishers athlete_performance athlete_gender  \
# 25299                        34             4:58:08              M
# 25300                        34             5:16:44              M
# 25301                        34             5:22:32              M
# 25302                        34             5:40:38              M
# 25303                        34             5:49:23              F
#
#        athlete_average_speed  athlete_id  athlete_age
# 25299                 10.063       23912           38
# 25300                  9.472       23913           34
# 25301                  9.301       23914           19
# 25302                  8.807       23915           32
# 25303                  8.587       23916           24

# %%
df3=df3=df2[['race_day','race_name','race_length','race_number_of_finishers','athlete_id','athlete_gender','athlete_age','athlete_performance','athlete_average_speed']]

# %%
df3.head()
# Out:
#          race_day             race_name race_length  race_number_of_finishers  \
# 25299  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25300  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25301  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25302  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25303  10.03.2018  Dirty Duo Trail Run         50km                        34
#
#        athlete_id athlete_gender  athlete_age athlete_performance  \
# 25299       23912              M           38             4:58:08
# 25300       23913              M           34             5:16:44
# 25301       23914              M           19             5:22:32
# 25302       23915              M           32             5:40:38
# 25303       23916              F           24             5:49:23
#
#        athlete_average_speed
# 25299                 10.063
# 25300                  9.472
# 25301                  9.301
# 25302                  8.807
# 25303                  8.587

# %%
#Dirty Duo Trail Run

# %%
df3[df3['race_name']=='Dirty Duo Trail Run ']
# Out:
#          race_day             race_name race_length  race_number_of_finishers  \
# 25299  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25300  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25301  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25302  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25303  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25304  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25305  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25306  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25307  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25308  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25311  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25312  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25313  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25314  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25315  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25316  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25317  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25318  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25320  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25321  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25322  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25323  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25324  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25325  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25326  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25327  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25328  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25329  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25330  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25331  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25332  10.03.2018  Dirty Duo Trail Run         50km                        34
#
#        athlete_id athlete_gender  athlete_age athlete_performance  \
# 25299       23912              M           38             4:58:08
# 25300       23913              M           34             5:16:44
# 25301       23914              M           19             5:22:32
# 25302       23915              M           32             5:40:38
# 25303       23916              F           24             5:49:23
# 25304       23917              F           45             5:54:02
# 25305       23918              M           48             5:57:37
# 25306       23919              M           33             6:04:32
# 25307       23920              M           41             6:05:29
# 25308       23921              M           37             6:17:00
# 25311       23924              M           36             6:26:29
# 25312       12145              M           33             6:35:26
# 25313       23925              F           45             6:44:31
# 25314       23926              M           55             6:46:02
# 25315       23927              F           32             6:46:15
# 25316       23928              F           34             6:46:27
# 25317       23929              M           46             6:47:55
# 25318       23930              M           54             7:03:36
# 25320       23932              M           41             7:27:44
# 25321       23933              M           58             7:32:24
# 25322       23934              M           56             7:36:05
# 25323       23935              M           50             7:37:16
# 25324       23936              M           37             7:46:03
# 25325       23937              M           61             7:57:50
# 25326       23938              M           54             7:58:02
# 25327       23939              F           44             8:10:14
# 25328       23940              M           46             8:17:29
# 25329       23941              M           49             8:52:59
# 25330       23942              F           48             9:08:50
# 25331       23943              M           67             9:15:24
# 25332       23944              F           28             9:28:39
#
#        athlete_average_speed
# 25299                 10.063
# 25300                  9.472
# 25301                  9.301
# 25302                  8.807
# 25303                  8.587
# 25304                  8.474
# 25305                  8.389
# 25306                  8.230
# 25307                  8.208
# 25308                  7.958
# 25311                  7.762
# 25312                  7.587
# 25313                  7.416
# 25314                  7.389
# 25315                  7.385
# 25316                  7.381
# 25317                  7.354
# 25318                  7.082
# 25320                  6.700
# 25321                  6.631
# 25322                  6.578
# 25323                  6.561
# 25324                  6.437
# 25325                  6.278
# 25326                  6.276
# 25327                  6.120
# 25328                  6.030
# 25329                  5.629
# 25330                  5.466
# 25331                  5.402
# 25332                  5.276

# %%
#23941

# %%
df3[df3['athlete_id']==23941]
# Out:
#           race_day                       race_name race_length  \
# 25329   10.03.2018            Dirty Duo Trail Run         50km
# 237338  09.06.2018  The Puddle Jumper Classic 50k         50km
# 325806  28.07.2018             Buckin' Hell 50 Km         50km
# 474831  19.08.2018                  Squamish 50km         50km
# 479249  18.08.2018                  Squamish 50mi         50mi
#
#         race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 25329                         34       23941              M           49
# 237338                        69       23941              M           49
# 325806                       144       23941              M           49
# 474831                       360       23941              M           49
# 479249                       369       23941              M           49
#
#        athlete_performance  athlete_average_speed
# 25329              8:52:59                  5.629
# 237338             8:57:56                  5.577
# 325806            10:11:36                  4.905
# 474831            10:44:08                  4.657
# 479249            15:38:56                  5.142

# %%
#Data Visualization

# %%
import seaborn as sns

# %%
sns.histplot(df3['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df3,x='race_length',hue='athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df3[df3['race_length']=='50mi']['athlete_average_speed'])

# %%
sns.violinplot(data=df3,x='race_length',y='athlete_average_speed',hue='athlete_gender',split=True,inner='quart',width=0.8)
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data=df3,x='athlete_age',y='athlete_average_speed',hue='athlete_gender')

# %%
#Data Analysis
#Average Speed by Length of Race and Gender

# %%
df3.groupby(['race_length','athlete_gender'])['athlete_average_speed'].mean()
# Out:
# race_length  athlete_gender
# 50km         F                 6.876505
#              M                 7.556174
# 50mi         F                 6.580681
#              M                 7.124712
# Name: athlete_average_speed, dtype: float64

# %%
#Best performance by age group in 50mi(minimum 20 races)

# %%
df3.query('race_length=="50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending=False).query('count>19')
# Out:
#                  mean  count
# athlete_age
# 28           7.727500     20
# 27           7.566450     20
# 31           7.440238     21
# 30           7.357731     26
# 32           7.345250     24
# 33           7.236148     27
# 38           7.199179     28
# 40           7.158087     23
# 35           6.931517     29
# 34           6.857391     23
# 39           6.833381     21
# 46           6.764192     26
# 37           6.683478     23
# 36           6.611300     20
# 49           6.597900     20
# 48           6.580409     22
# 44           6.519357     28

# %%
#Worst performance by age group in 50mi(minimum 10 races)

# %%
df3.query('race_length=="50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending=True).query('count>9')
# Out:
#                  mean  count
# athlete_age
# 55           6.211250     12
# 51           6.296077     13
# 52           6.407857     14
# 41           6.412765     17
# 43           6.498556     18
# 44           6.519357     28
# 48           6.580409     22
# 42           6.595421     19
# 49           6.597900     20
# 36           6.611300     20
# 37           6.683478     23
# 58           6.693545     11
# 46           6.764192     26
# 26           6.795353     17
# 39           6.833381     21
# 34           6.857391     23
# 50           6.915222     18
# 35           6.931517     29
# 40           7.158087     23
# 38           7.199179     28
# 47           7.216182     11
# 33           7.236148     27
# 32           7.345250     24
# 30           7.357731     26
# 45           7.439947     19
# 31           7.440238     21
# 29           7.561647     17
# 27           7.566450     20
# 28           7.727500     20
# 25           7.733091     11

# %%
df3['race_month']=df3['race_day'].str.split('.').str.get(1).astype(int)

# %%
df3.head()
# Out:
#          race_day             race_name race_length  race_number_of_finishers  \
# 25299  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25300  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25301  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25302  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25303  10.03.2018  Dirty Duo Trail Run         50km                        34
#
#        athlete_id athlete_gender  athlete_age athlete_performance  \
# 25299       23912              M           38             4:58:08
# 25300       23913              M           34             5:16:44
# 25301       23914              M           19             5:22:32
# 25302       23915              M           32             5:40:38
# 25303       23916              F           24             5:49:23
#
#        athlete_average_speed  race_month
# 25299                 10.063           3
# 25300                  9.472           3
# 25301                  9.301           3
# 25302                  8.807           3
# 25303                  8.587           3

# %%
df3['race_season']=df3['race_month'].apply(lambda x:'Winter' if x>11 else 'Fall' if x>8 else 'Summer' if x>5 else 'Spring' if x>2 else 'Winter')

# %%
df3.head()
# Out:
#          race_day             race_name race_length  race_number_of_finishers  \
# 25299  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25300  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25301  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25302  10.03.2018  Dirty Duo Trail Run         50km                        34
# 25303  10.03.2018  Dirty Duo Trail Run         50km                        34
#
#        athlete_id athlete_gender  athlete_age athlete_performance  \
# 25299       23912              M           38             4:58:08
# 25300       23913              M           34             5:16:44
# 25301       23914              M           19             5:22:32
# 25302       23915              M           32             5:40:38
# 25303       23916              F           24             5:49:23
#
#        athlete_average_speed  race_month race_season
# 25299                 10.063           3      Spring
# 25300                  9.472           3      Spring
# 25301                  9.301           3      Spring
# 25302                  8.807           3      Spring
# 25303                  8.587           3      Spring

# %%
#Average speed by Race Season

# %%
df3.groupby('race_season')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending=False)
# Out:
#                  mean  count
# race_season
# Spring       7.809734   1136
# Fall         7.341772   1304
# Winter       7.290311    135
# Summer       6.786107   1755

# %%
#Average speed by Race Season[50mi]

# %%
df3.query('race_length=="50mi"').groupby('race_season')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending=False)
# Out:
#                   mean  count
# race_season
# Fall         11.339625      8
# Spring        7.569599    162
# Winter        7.423359     78
# Summer        6.529961    432
